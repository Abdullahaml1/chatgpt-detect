# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullahaml1/chatgpt-detect/blob/main/chatgpt_detect_scripts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chatgpt Detector Implmentation of [this paper](https://arxiv.org/pdf/2301.07597.pdf)

# %% [markdown]
# # Custom Model Traing Results
# Best Dev check point
# ```
# # of steps=1500, Avg Train Loss=0.000501, Avg Dev Loss=0.000255, Train Acc=0.997625, Dev Acc=0.999170, Time: 2737.913234
# ```
# with Test Accuracy
# ```
# Test Accuracy=0.996472, Test Avg loss=7.452892782085414e-05
# ```
#
# but we got higher test accuracy when continuing training to the end:
# ```
# Test Acc=0.9985471149854711, Test Loss=0.0003716888740479377
# ```
#
# Original model Test Result:
# ```
# Test Accuracy=0.990660, Test Avg loss=0.0015800070495415447
# ```

# %%
# !git clone https://github.com/Abdullahaml1/chatgpt-detect.git
# Out:
# Cloning into 'chatgpt-detect'...
# remote: Enumerating objects: 63, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 63 (delta 19), reused 60 (delta 19), pack-reused 0
# Unpacking objects: 100% (63/63), 12.25 KiB | 447.00 KiB/s, done.

# %%
! pip install transformers datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 53.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 48.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 29.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 101.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 14.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 28.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 62.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.1 MB/s eta 0:00:00
# ...

# %%
# !python chatgpt-detect/chatgpt-detect.py --test --test-type=paper --batch-size=128
# Out:
# Number of Classes= 2
# Found cached dataset hc3 (/root/.cache/huggingface/datasets/Hello-SimpleAI___hc3/all/1.1.0/5af5910f9f3fe7aace30e32ad4c1ab776ca08183d00e9b2a091308549f69f683)
# Lenght of dataset 48189
# start Testing ..........
# 151it [02:29,  1.01it/s]
# Test Accuracy=0.990660, Test Avg loss=0.0015800070495415447

# %%
# !python chatgpt-detect/chatgpt-detect.py --checkpoint=500 --batch-size=16
# Out:
# Number of Classes= 2
# Found cached dataset hc3 (/root/.cache/huggingface/datasets/Hello-SimpleAI___hc3/all/1.1.0/5af5910f9f3fe7aace30e32ad4c1ab776ca08183d00e9b2a091308549f69f683)
# Lenght of dataset 48189
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
# !python chatgpt-detect/chatgpt-detect.py --test --test-type=model --batch-size=128 \
                    --load-model='chat-detect-model.pt'
# Out:
# Number of Classes= 2
# Found cached dataset hc3 (/root/.cache/huggingface/datasets/Hello-SimpleAI___hc3/all/1.1.0/5af5910f9f3fe7aace30e32ad4c1ab776ca08183d00e9b2a091308549f69f683)
# Lenght of dataset 48189
# start Testing ..........
# 38it [02:24,  3.82s/it]
# Test Accuracy=0.996472, Test Avg loss=7.452892782085414e-05

# %%
# !ls
# Out:
# chat-detect-model.pt  chatgpt-detect  chatgpt_detect.png  sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
! cp chatgpt_detect.png "/content/drive/My Drive/"
! cp chat-detect-model.pt "/content/drive/My Drive/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! cd chatgpt-detect && git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 1), reused 3 (delta 1), pack-reused 0
# Unpacking objects: 100% (3/3), 338 bytes | 338.00 KiB/s, done.
# From https://github.com/Abdullahaml1/chatgpt-detect
#    1825c7c..68bab6c  main       -> origin/main
# Updating 1825c7c..68bab6c
# Fast-forward
#  chatgpt-detect.py | 5 +----
#  1 file changed, 1 insertion(+), 4 deletions(-)
